# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.12.2)

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import matplotlib.pyplot as plt
from PIL import Image

# 이미지 열기
image_list = [
    Image.open('/content/drive/MyDrive/회사/DNB_kt.jpg'),
    Image.open('/content/drive/MyDrive/회사/DNB_media.jpg'),
    Image.open('/content/drive/MyDrive/회사/DNB_ai.jpg'),
    Image.open('/content/drive/MyDrive/회사/DNB_bigdata.jpg'),
    Image.open('/content/drive/MyDrive/회사/DNB_cloud.jpg'),
    Image.open('/content/drive/MyDrive/회사/DNB_bigtech.jpg')
]

# 검색하고자 하는 키워드 설정
keyword_list = ['kt', '미디어 산업', 'AI', '빅데이터', '클라우드', '빅테크']

# 뉴스기사 크롤링
def daily_briefing(keyword):
  url = f'https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query={keyword}'
  headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.864.59 Safari/537.36 Edg/91.0.864.59'}
  search = requests.get(url,headers = headers)

  soup = BeautifulSoup(search.text, 'html.parser')

  # 뉴스기사 리스트 가져오기
  news_list = soup.select('#main_pack > section > div > div.group_news > ul > li')

  count = 0
  for article in news_list:
    if count >= 7:
      break
    articles = article.select_one('a.news_tit')
    print(f"   ◾\033[1m{articles.text}\033[0m")
    print("  ", articles['href'])
    count += 1


# 출력
plt.imshow(Image.open('/content/drive/MyDrive/회사/DNB_title.jpg'))
plt.axis('off')

for img, keyword in zip(image_list, keyword_list):
  fig, ax = plt.subplots()
  plt.imshow(img)
  plt.axis('off')  # 축 숨기기
  plt.show()
  daily_briefing(keyword)
  print()
# Out:
#    ◾KT, 'AI 위협메일 차단서비스'로 기업 대상 해킹 막았다
#    https://www.newsis.com/view/NISX20250227_0003080513
#    ◾통신 기업 KT가 '스마트폰 자제 캠페인'에 나선 이유 [현장]
#    http://www.inews24.com/view/1818105
#    ◾KT, ‘AI 위협메일 차단 서비스’로 기업 보안 지킨다
#    http://www.segye.com/newsView/20250227510249?OutUrl=naver
#    ◾KT, 새로운 'iPhone 16e' 출시
#    https://www.yna.co.kr/view/PYH20250228025600013?input=1196m
#    ◾KT, 새로운 아이폰 16e 출시
#    http://www.econonews.co.kr/news/articleView.html?idxno=377178
#    ◾KT, 래블업과 GPU 구독 서비스 협력 나선다
#    https://www.hankyung.com/article/202502273912i
#    ◾KT, 래블업과 GPU 구독 서비스 협력...“AI생태계 확장”
#    http://www.edaily.co.kr/news/newspath.asp?newsid=02925766642074784
#    ◾코바코-시청자미디어재단, 미디어산업 발전 업무협약
#    https://www.yna.co.kr/view/AKR20250225079400017?input=1195m
#    ◾여의도·상암 이은 미디어산업 메카…고양시 방송영상밸리 개발 본격화
#    https://ilyo.co.kr/?ac=article_view&entry_id=487813
#    ◾MJ플렉스, '제13회 대한민국교육대상' 미디어·디자이너 취업 부문 대상...
#    https://www.ezyeconomy.com/news/articleView.html?idxno=208750
#    ◾고양방송영상밸리 미디어 허브 왕좌 노린다
#    https://m.skyedaily.com/news_view.html?ID=264156
#    ◾SK텔레콤, MWC25서 AI 기반 산업·보안·미디어 기술 공개
#    https://www.fetv.co.kr/news/article.html?no=187412
#    ◾고양방송영상밸리, 수도권 서북부 미디어산업 중심 도약
#    https://www.newscj.com/news/articleView.html?idxno=3238036
#    ◾속초시, 대포동 해양산업단지에 미디어센터 조성
#    https://www.mbceg.co.kr/post/122921
#    ◾오픈AI, 최신 AI 모델 GPT-4.5 출시…"대화형 모델 최강"
#    https://www.yna.co.kr/view/AKR20250228004100091?input=1195m
#    ◾국표원, 아시아·태평양 지역 AI 표준협력 강화한다
#    https://www.newsis.com/view/NISX20250227_0003081681
#    ◾기획부터 디자인까지…LGU+, MWC서 AI가 만든 전시관 공개
#    https://www.news1.kr/it-science/general-it/5704512
#    ◾카카오, 조직 개편 단행…카카오톡·AI 핵심 사업 통합
#    https://news.tf.co.kr/read/economy/2183427.htm
#    ◾SKT, 美 아이온큐와 양자컴 동맹…"SK AI에 양자 접목"
#    https://www.newsis.com/view/NISX20250227_0003080355
#    ◾해남에 세계 최대 ‘AI 데이터센터’ 들어선다
#    http://www.segye.com/newsView/20250227515389?OutUrl=naver
#    ◾갤럭시 S25, 국내 출시 3주만에 100만대 팔려…역대 최고 속도
#    https://www.newsis.com/view/NISX20250228_0003081895
#    ◾서울시-시립대, 슈퍼컴퓨터 활용 빅데이터 해커톤 6월 개최
#    https://www.yna.co.kr/view/AKR20250228041800004?input=1195m
#    ◾기보, AI·빅데이터 활용 감사시스템 특허 출원
#    https://biz.heraldcorp.com/article/10430837?ref=naver
#    ◾[브랜드평판] 해운 상장기업 2025년 2월 빅데이터 1위 HMM, 2위 팬오션, ...
#    https://www.cbci.co.kr/news/articleView.html?idxno=487590
#    ◾해남에 세계 최대 ‘AI 데이터센터’ 들어선다
#    http://www.segye.com/newsView/20250227515389?OutUrl=naver
#    ◾국립목포대, MNU AI 빅데이터 센터 개소
#    https://dhnews.co.kr/news/view/1065601108491287
#    ◾금감원 "빅테크에 컨설팅 중심 검사 추진…금융사고엔 엄중 대응"
#    https://www.newsis.com/view/NISX20250227_0003081361
#    ◾"빅데이터로 빈집 예측"…한국부동산원, 디지털 혁신 프로젝트 선정
#    https://www.news1.kr/realestate/general/5704004
#    ◾아마존, 첫 양자칩 공개…'클라우드 빅3' 전장 양자칩으로 이동[송영찬...
#    https://www.hankyung.com/article/202502284858i
#    ◾오픈 클라우드 플랫폼 얼라이언스, 제4차 정기총회 개최
#    https://zdnet.co.kr/view/?no=20250227194903
#    ◾카카오엔터프라이즈, 몽골 과기대 카카오클라우드 인턴십 프로그램 성료
#    https://www.newspim.com/news/view/20250228000256
#    ◾NHN클라우드 서버 장애로 지자체 홈피 마비…2시간만에 복구(종합)
#    https://www.yna.co.kr/view/AKR20250226070151017?input=1195m
#    ◾옵스나우, 하이브리드 클라우드 관리 플랫폼 '옵스나우 프라임' 상반기...
#    https://www.newsis.com/view/NISX20250228_0003082367
#    ◾아이티센엔텍, AI 클라우드 컴퓨팅 수혜 전망에 급등[특징주]
#    http://www.edaily.co.kr/news/newspath.asp?newsid=02437046642075112
#    ◾구글 클라우드, ‘개인용 제미나이 코드 어시스트’ 무료 공개
#    https://biz.chosun.com/it-science/ict/2025/02/26/SLK2VSZH7BBFJNW5E5FNXYABMI/?utm_source=naver&utm_medium=original&utm_campaign=biz
#    ◾금감원 "빅테크에 컨설팅 중심 검사 추진…금융사고엔 엄중 대응"
#    https://www.newsis.com/view/NISX20250227_0003081361
#    ◾해남에 세계 최대 ‘AI 데이터센터’ 들어선다
#    http://www.segye.com/newsView/20250227515389?OutUrl=naver
#    ◾돈 더 불린 빅테크 거물들… ‘슈퍼 억만장자’ 등극
#    https://www.seoul.co.kr/news/international/2025/02/27/20250227014006?wlog_tag3=naver
#    ◾아마존도 자체 개발 양자컴 공개...빅테크 경쟁 가속화
#    https://view.asiae.co.kr/article/2025022810240171906
#    ◾[기획] 삼성·현대차 `처절한` 생존동맹
#    https://www.dt.co.kr/contents.html?article_no=2025022802100132064001&ref=naver
#    ◾해남 솔라시도에 세계 최대 규모 'AI슈퍼클러스터 허브' 추진
#    https://www.yna.co.kr/view/AKR20250227066700054?input=1195m
#    ◾전남도 세계 최대 규모 AI 슈퍼클러스터 허브 구축한다
#    https://www.donga.com/news/Society/article/all/20250227/131114118/1
